# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## Getting the data -
# download from https://www.kaggle.com/c/fake-news/data and use train.csv file

# %%
data = pd.read_csv('train.csv')

# %%
data.head()
# Out:
#    id                                              title              author  \
# 0   0  House Dem Aide: We Didn’t Even See Comey’s Let...       Darrell Lucus
# 1   1  FLYNN: Hillary Clinton, Big Woman on Campus - ...     Daniel J. Flynn
# 2   2                  Why the Truth Might Get You Fired  Consortiumnews.com
# 3   3  15 Civilians Killed In Single US Airstrike Hav...     Jessica Purkiss
# 4   4  Iranian woman jailed for fictional unpublished...      Howard Portnoy
#
#                                                 text  label
# 0  House Dem Aide: We Didn’t Even See Comey’s Let...      1
# 1  Ever get the feeling your life circles the rou...      0
# 2  Why the Truth Might Get You Fired October 29, ...      1
# 3  Videos 15 Civilians Killed In Single US Airstr...      1
# 4  Print \nAn Iranian woman has been sentenced to...      1

# %%
X = data['text']
y = data['label']

# %%
test = pd.read_csv('test.csv')

# %%
X_train = X
y_train = y
X_test = test['text']

# %% [markdown]
# ## Using countvectorizer

# %%
# fill na's to use the countvectorizer
X_train = X_train.fillna('')
X_test= X_test.fillna('')

count_vectorizer = CountVectorizer()

#getting the vector repr, fit and transform
train_counts = count_vectorizer.fit_transform(X_train.values)
test_counts = count_vectorizer.transform(X_test.values)

# %%
# use Logistic model
classifier = LogisticRegression()
classifier.fit(train_counts, y_train)
# Out:
# /Users/shreejaya/.local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
y_pred_train = classifier.predict(train_counts)
y_pred_test = classifier.predict(test_counts)

# %%
print ("training accuracy is ", accuracy_score(y_train, y_pred_train))
# Out:
# training accuracy is  0.9999038461538462

# %%
#print ("validation accuracy is ", accuracy_score(y_test, y_pred_test))
# Out:
# validation accuracy is  0.9556089743589744

# %%
y_pred_test
# Out:
# array([0, 1, 1, ..., 0, 1, 0])

# %%
test.head()
# Out:
#       id                                              title  \
# 0  20800  Specter of Trump Loosens Tongues, if Not Purse...
# 1  20801  Russian warships ready to strike terrorists ne...
# 2  20802  #NoDAPL: Native American Leaders Vow to Stay A...
# 3  20803  Tim Tebow Will Attempt Another Comeback, This ...
# 4  20804                    Keiser Report: Meme Wars (E995)
#
#                     author                                               text
# 0         David Streitfeld  PALO ALTO, Calif.  —   After years of scorning...
# 1                      NaN  Russian warships ready to strike terrorists ne...
# 2            Common Dreams  Videos #NoDAPL: Native American Leaders Vow to...
# 3            Daniel Victor  If at first you don’t succeed, try a different...
# 4  Truth Broadcast Network  42 mins ago 1 Views 0 Comments 0 Likes 'For th...

# %%
chk = pd.DataFrame(test['id']).join(pd.DataFrame(y_pred_test))

# %%
chk.columns = ['id','label']

# %%
chk.head()
# Out:
#       id  label
# 0  20800      0
# 1  20801      1
# 2  20802      1
# 3  20803      0
# 4  20804      1

# %%
chk.to_csv('sub_2Apr.csv', index=False)

# %%
# Out:
#   File "<ipython-input-40-fdd7736cdd10>", line 1
#     text = " Washington (CNN)The nation's top infectious disease expert said Thursday he doesn't understand why every state hasn't issued stay-at-home orders as novel coronavirus cases continue to surge across the US."I don't understand why that's not happening," Dr. Anthony Fauci told CNN's Anderson Cooper during CNN's coronavirus town hall.More than 30 states and the District of Columbia have ordered their residents to stay at home. Fauci said governors that have held out thus far "really should" reconsider with the number of US cases passing 236,000 on Thursday and continuing to climb.
#                                                                                                                                                                                                                           ^
# SyntaxError: invalid syntax

# %%
read_json('empire_news_pull.json')
# Out:
#   Multiple People Hospitalized, Several Arrested During ‘Rush Limbaugh Has Cancer’ Celebration in Boston  \
# 0  https://empirenews.net/multiple-people-hospita...
# 1  0\n\nBOSTON, MA\n\nOver a dozen people were ho...
#
#   Trump To Host Massive ‘I Beat Impeachment’ Party at White House This Weekend  \
# 0  https://empirenews.net/trump-to-host-massive-i...
# 1  0\n\nWASHINGTON, D.C.\n\nPresident Trump has d...
#
#   Parent Company of Corona Beer Sues China Over Bad Press During Their Coronavirus Scare  \
# 0  https://empirenews.net/parent-company-of-coron...
# 1  0\n\nMEXICO CITY, Mexico –\n\nAnheuser-Busch I...
#
#   Michelle Obama Files For Divorce After Shocking Revelation; Barack Obama Admits: ‘I’m Gay!’  \
# 0  https://empirenews.net/michelle-obama-files-fo...
# 1  0\n\nPHILADELPHIA, PA\n\nFormer President Bara...
#
#   Gizmo Files Lawsuit Against Disney Over ‘Baby Yoda’, Claims Company Stole His Likeness  \
# 0  https://empirenews.net/gizmo-files-lawsuit-aga...
# ...

# %%
import json

with open('empire_news_pull.json') as f:
    data = json.load(f)

# %%
data
# Out:
# {'Multiple People Hospitalized, Several Arrested During ‘Rush Limbaugh Has Cancer’ Celebration in Boston': ['https://empirenews.net/multiple-people-hospitalized-several-arrested-during-rush-limbaugh-has-cancer-celebration-in-boston/',
# ...

# %% [markdown]
# ## Using tfidf vectorizer

# %%
#getting the vector repr, fit and transform
tfidf_vectorizer = TfidfVectorizer()
train_counts = tfidf_vectorizer.fit_transform(X_train.values)
test_counts = tfidf_vectorizer.transform(X_test.values)

# %%
# use Logistic model
classifier = LogisticRegression()
classifier.fit(train_counts, y_train)
# Out:
# /Users/shreejaya/.local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
y_pred_train = classifier.predict(train_counts)
y_pred_test = classifier.predict(test_counts)

# %%
print ("training accuracy is ", accuracy_score(y_train, y_pred_train))
# Out:
# training accuracy is  0.9691620879120879

# %%
print ("validation accuracy is ", accuracy_score(y_test, y_pred_test))
# Out:
# validation accuracy is  0.9423076923076923
